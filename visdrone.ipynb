# %% [markdown]
# # visdrone:数据集理解
# 加载数据集，理解annotation的具体含义

# %%
import os

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16.0, 16.0)
#%matplotlib inline
import matplotlib.image as mpimg

# %% [markdown]
# ## test1:读取图片并显示

# %%
base_path = r"H:\deepLearning\dataset\visdrone\Task 1 - Object Detection in Images\train\VisDrone2019-DET-train"
images_path = os.path.join(base_path,"images")
annotations_path = os.path.join(base_path,"annotations")
print(images_path)
print(annotations_path)
# Out:
# H:\deepLearning\dataset\visdrone\Task 1 - Object Detection in Images\train\VisDrone2019-DET-train\images
# H:\deepLearning\dataset\visdrone\Task 1 - Object Detection in Images\train\VisDrone2019-DET-train\annotations

# %%
img_files = os.listdir(images_path)
print(img_files[:2])
# Out:
# ['0000002_00005_d_0000014.jpg', '0000002_00448_d_0000015.jpg']

# %%
img_path = os.path.join(images_path,img_files[0])
img = mpimg.imread(img_path)
plt.imshow(img)
plt.show()

# %%
height,width = img.shape[:2]
print(f"img width={width},height={height}")
# Out:
# img width=960,height=540

# %% [markdown]
# ## 叠加标签

# %%
label_files = os.listdir(annotations_path)
label_files[0]
# Out:
# '0000002_00005_d_0000014.txt'

# %%
label_path = os.path.join(annotations_path,label_files[0])
print(label_path)
# Out:
# H:\deepLearning\dataset\visdrone\Task 1 - Object Detection in Images\train\VisDrone2019-DET-train\annotations\0000002_00005_d_0000014.txt

# %% [markdown]
# ### 读取图片对应的标签并存到np array

# %%
lbls = None
with open(label_path) as f:
    lbls = f.readlines()
    print(lbls)
# Out:
# ['684,8,273,116,0,0,0,0\n', '406,119,265,70,0,0,0,0\n', '255,22,119,128,0,0,0,0\n', '1,3,209,78,0,0,0,0\n', '708,471,74,33,1,4,0,1\n', '639,425,61,46,1,4,0,0\n', '594,399,64,51,1,4,0,0\n', '562,390,61,38,1,4,0,0\n', '540,372,65,33,1,4,0,1\n', '514,333,68,35,1,4,0,0\n', '501,317,64,31,1,4,0,1\n', '501,299,45,28,1,4,0,1\n', '489,284,48,27,1,4,0,1\n', '463,262,48,29,1,4,0,0\n', '458,252,49,22,1,4,0,1\n', '448,242,45,20,1,4,0,1\n', '442,230,49,19,1,4,0,1\n', '439,214,45,21,1,4,0,1\n', '429,208,42,19,1,4,0,1\n', '420,199,43,20,1,4,0,1\n', '398,188,41,18,1,4,0,1\n', '46,391,14,26,1,2,0,0\n', '421,433,74,44,1,4,0,1\n', '369,346,64,34,1,4,0,0\n', '398,410,72,46,1,4,0,1\n', '394,393,70,36,1,4,0,1\n', '377,364,71,38,1,4,0,0\n', '357,312,58,31,1,4,0,0\n', '359,298,54,22,1,4,0,2\n', '348,283,43,28,1,5,0,1\n', '345,271,52,19,1,4,0,1\n', '340,260,60,18,1,5,0,1\n', '340,250,52,16,1,4,0,1\n', '332,231,54,22,1,5,0,1\n', '323,213,45,25,1,5,0,0\n', '317,195,45,31,1,6,0,1\n', '316,188,36,15,1,4,0,2\n', '308,179,44,17,1,4,0,1\n', '345,163,37,18,1,4,0,0\n', '384,164,26,22,1,4,0,1\n', '43,398,18,17,1,10,0,1\n', '324,167,14,6,1,3,0,0\n', '362,143,30,18,1,4,1,0\n', '310,150,36,15,1,4,0,0\n', '258,375,30,43,1,4,0,2\n', '218,348,18,28,1,7,0,0\n', '249,297,23,30,1,4,0,2\n', '0,298,26,34,1,8,1,0\n', '33,279,24,30,1,4,0,0\n', '47,243,26,28,1,4,0,0\n', '72,202,28,28,1,5,0,0\n', '87,125,15,15,1,4,0,0\n', '170,113,15,13,1,4,0,0\n', '102,81,13,13,1,4,0,0\n', '415,207,5,9,1,1,0,0\n', '428,197,8,13,1,1,0,1\n', '232,385,13,31,0,11,0,0\n', '234,391,8,17,1,2,0,2\n', '879,256,12,19,1,1,0,0\n', '897,225,8,17,1,1,0,0\n', '57,341,11,20,1,2,0,0\n', '55,345,13,19,1,3,0,1\n', '55,313,10,20,1,1,0,0\n', '53,320,14,13,1,3,0,1\n', '232,236,7,14,1,1,0,1\n', '237,236,6,14,1,1,0,1\n', '193,235,7,13,1,2,0,1\n', '192,241,11,11,1,10,0,1\n', '178,234,6,10,1,2,0,2\n', '177,237,8,12,1,10,0,1\n', '117,202,7,11,1,2,0,1\n', '118,206,7,12,1,10,0,1\n', '59,211,9,13,1,1,0,0\n', '86,194,8,17,1,1,0,2\n', '219,118,7,10,1,1,0,0\n', '193,99,6,10,1,10,0,2\n', '137,115,6,9,1,2,0,1\n', '109,107,4,7,1,2,0,1\n', '109,110,5,8,1,10,0,1\n', '87,102,9,13,1,8,0,1\n', '112,100,4,9,1,2,0,1\n', '59,280,11,18,1,1,0,0\n', '89,81,10,10,1,5,1,0\n', '136,119,6,8,1,10,0,1\n', '841,487,21,26,1,10,0,0\n', '912,139,34,73,0,0,0,0\n', '223,345,8,11,1,2,0,2\n', '329,161,7,11,1,2,0,0\n']

# %%
lbls_np = np.zeros((len(lbls),8))
print(lbls_np.shape)
for i,lbl in enumerate(lbls):
    res = [int(num) for num in lbl.split(',')]
    lbls_np[i,:] = np.array(res)
lbls_np
# Out:
# (88, 8)
# array([[684.,   8., 273., 116.,   0.,   0.,   0.,   0.],
#        [406., 119., 265.,  70.,   0.,   0.,   0.,   0.],
#        [255.,  22., 119., 128.,   0.,   0.,   0.,   0.],
#        [  1.,   3., 209.,  78.,   0.,   0.,   0.,   0.],
#        [708., 471.,  74.,  33.,   1.,   4.,   0.,   1.],
#        [639., 425.,  61.,  46.,   1.,   4.,   0.,   0.],
#        [594., 399.,  64.,  51.,   1.,   4.,   0.,   0.],
#        [562., 390.,  61.,  38.,   1.,   4.,   0.,   0.],
#        [540., 372.,  65.,  33.,   1.,   4.,   0.,   1.],
#        [514., 333.,  68.,  35.,   1.,   4.,   0.,   0.],
#        [501., 317.,  64.,  31.,   1.,   4.,   0.,   1.],
#        [501., 299.,  45.,  28.,   1.,   4.,   0.,   1.],
#        [489., 284.,  48.,  27.,   1.,   4.,   0.,   1.],
#        [463., 262.,  48.,  29.,   1.,   4.,   0.,   0.],
#        [458., 252.,  49.,  22.,   1.,   4.,   0.,   1.],
#        [448., 242.,  45.,  20.,   1.,   4.,   0.,   1.],
#        [442., 230.,  49.,  19.,   1.,   4.,   0.,   1.],
#        [439., 214.,  45.,  21.,   1.,   4.,   0.,   1.],
#        [429., 208.,  42.,  19.,   1.,   4.,   0.,   1.],
#        [420., 199.,  43.,  20.,   1.,   4.,   0.,   1.],
#        [398., 188.,  41.,  18.,   1.,   4.,   0.,   1.],
#        [ 46., 391.,  14.,  26.,   1.,   2.,   0.,   0.],
#        [421., 433.,  74.,  44.,   1.,   4.,   0.,   1.],
#        [369., 346.,  64.,  34.,   1.,   4.,   0.,   0.],
#        [398., 410.,  72.,  46.,   1.,   4.,   0.,   1.],
#        [394., 393.,  70.,  36.,   1.,   4.,   0.,   1.],
#        [377., 364.,  71.,  38.,   1.,   4.,   0.,   0.],
#        [357., 312.,  58.,  31.,   1.,   4.,   0.,   0.],
#        [359., 298.,  54.,  22.,   1.,   4.,   0.,   2.],
#        [348., 283.,  43.,  28.,   1.,   5.,   0.,   1.],
#        [345., 271.,  52.,  19.,   1.,   4.,   0.,   1.],
#        [340., 260.,  60.,  18.,   1.,   5.,   0.,   1.],
#        [340., 250.,  52.,  16.,   1.,   4.,   0.,   1.],
#        [332., 231.,  54.,  22.,   1.,   5.,   0.,   1.],
#        [323., 213.,  45.,  25.,   1.,   5.,   0.,   0.],
#        [317., 195.,  45.,  31.,   1.,   6.,   0.,   1.],
#        [316., 188.,  36.,  15.,   1.,   4.,   0.,   2.],
#        [308., 179.,  44.,  17.,   1.,   4.,   0.,   1.],
#        [345., 163.,  37.,  18.,   1.,   4.,   0.,   0.],
#        [384., 164.,  26.,  22.,   1.,   4.,   0.,   1.],
#        [ 43., 398.,  18.,  17.,   1.,  10.,   0.,   1.],
#        [324., 167.,  14.,   6.,   1.,   3.,   0.,   0.],
#        [362., 143.,  30.,  18.,   1.,   4.,   1.,   0.],
#        [310., 150.,  36.,  15.,   1.,   4.,   0.,   0.],
#        [258., 375.,  30.,  43.,   1.,   4.,   0.,   2.],
#        [218., 348.,  18.,  28.,   1.,   7.,   0.,   0.],
#        [249., 297.,  23.,  30.,   1.,   4.,   0.,   2.],
#        [  0., 298.,  26.,  34.,   1.,   8.,   1.,   0.],
#        [ 33., 279.,  24.,  30.,   1.,   4.,   0.,   0.],
#        [ 47., 243.,  26.,  28.,   1.,   4.,   0.,   0.],
#        [ 72., 202.,  28.,  28.,   1.,   5.,   0.,   0.],
#        [ 87., 125.,  15.,  15.,   1.,   4.,   0.,   0.],
#        [170., 113.,  15.,  13.,   1.,   4.,   0.,   0.],
#        [102.,  81.,  13.,  13.,   1.,   4.,   0.,   0.],
#        [415., 207.,   5.,   9.,   1.,   1.,   0.,   0.],
#        [428., 197.,   8.,  13.,   1.,   1.,   0.,   1.],
#        [232., 385.,  13.,  31.,   0.,  11.,   0.,   0.],
#        [234., 391.,   8.,  17.,   1.,   2.,   0.,   2.],
#        [879., 256.,  12.,  19.,   1.,   1.,   0.,   0.],
#        [897., 225.,   8.,  17.,   1.,   1.,   0.,   0.],
#        [ 57., 341.,  11.,  20.,   1.,   2.,   0.,   0.],
#        [ 55., 345.,  13.,  19.,   1.,   3.,   0.,   1.],
#        [ 55., 313.,  10.,  20.,   1.,   1.,   0.,   0.],
#        [ 53., 320.,  14.,  13.,   1.,   3.,   0.,   1.],
#        [232., 236.,   7.,  14.,   1.,   1.,   0.,   1.],
#        [237., 236.,   6.,  14.,   1.,   1.,   0.,   1.],
#        [193., 235.,   7.,  13.,   1.,   2.,   0.,   1.],
#        [192., 241.,  11.,  11.,   1.,  10.,   0.,   1.],
#        [178., 234.,   6.,  10.,   1.,   2.,   0.,   2.],
#        [177., 237.,   8.,  12.,   1.,  10.,   0.,   1.],
#        [117., 202.,   7.,  11.,   1.,   2.,   0.,   1.],
#        [118., 206.,   7.,  12.,   1.,  10.,   0.,   1.],
#        [ 59., 211.,   9.,  13.,   1.,   1.,   0.,   0.],
#        [ 86., 194.,   8.,  17.,   1.,   1.,   0.,   2.],
#        [219., 118.,   7.,  10.,   1.,   1.,   0.,   0.],
#        [193.,  99.,   6.,  10.,   1.,  10.,   0.,   2.],
#        [137., 115.,   6.,   9.,   1.,   2.,   0.,   1.],
#        [109., 107.,   4.,   7.,   1.,   2.,   0.,   1.],
#        [109., 110.,   5.,   8.,   1.,  10.,   0.,   1.],
#        [ 87., 102.,   9.,  13.,   1.,   8.,   0.,   1.],
#        [112., 100.,   4.,   9.,   1.,   2.,   0.,   1.],
#        [ 59., 280.,  11.,  18.,   1.,   1.,   0.,   0.],
#        [ 89.,  81.,  10.,  10.,   1.,   5.,   1.,   0.],
#        [136., 119.,   6.,   8.,   1.,  10.,   0.,   1.],
#        [841., 487.,  21.,  26.,   1.,  10.,   0.,   0.],
#        [912., 139.,  34.,  73.,   0.,   0.,   0.,   0.],
#        [223., 345.,   8.,  11.,   1.,   2.,   0.,   2.],
#        [329., 161.,   7.,  11.,   1.,   2.,   0.,   0.]])

# %% [markdown]
# ## 生成类别颜色

# %%
def draw_colors(colors):
    frame = np.zeros((4*32,4*32,3))
    for i,color in enumerate(colors):
        ix = i//4
        iy = i%4
        frame[ix*32:(ix+1)*32,iy*32:(iy+1)*32,:] = np.array(color)
    plt.imshow(frame.astype('uint8'))

# %% [markdown]
# ### 连续颜色

# %%
def generate_colors(num):
    '''
    根据目标数量，生成相同数量的颜色
    '''
    colors = []
    if num == 1:
        colors = [(255,0,0)]
    elif num == 2:
        colors = [(255,0,0),(0,255,0)]
    else:
        step = 255 // (num//3 + 1)
        color = [0,0,0]
        for i in range(3):
            for j in range(0,255,step):
                color[i] = 255 - j
                colors.append(tuple(color))
            color[i] = 0
    return colors[:num]

# %%
color_num = 16
colors = generate_colors(color_num)
print(colors)
frame = np.zeros((4*32,4*32,3))
for i,color in enumerate(colors):
    ix = i//4
    iy = i%4
    frame[ix*32:(ix+1)*32,iy*32:(iy+1)*32,:] = np.array(color)
# Out:
# [(255, 0, 0), (213, 0, 0), (171, 0, 0), (129, 0, 0), (87, 0, 0), (45, 0, 0), (3, 0, 0), (0, 255, 0), (0, 213, 0), (0, 171, 0), (0, 129, 0), (0, 87, 0), (0, 45, 0), (0, 3, 0), (0, 0, 255), (0, 0, 213)]

# %%
plt.imshow(frame.astype('uint8'))

# %% [markdown]
# ### 加载调色板(效果最好)

# %%
import pickle as pkl
colors = pkl.load(open("pallete", "rb"))
colors = np.array(colors)

# %%
print(f"there {len(colors)} different colors in pallete")
# Out:
# there 100 different colors in pallete

# %%
import random
color = random.choice(colors)

# %%
idx = np.random.choice(range(len(colors)),16)
colors = colors[idx]

# %%
frame = np.zeros((4*32,4*32,3))
for i,color in enumerate(colors):
    ix = i//4
    iy = i%4
    frame[ix*32:(ix+1)*32,iy*32:(iy+1)*32,:] = np.array(color)

# %%
plt.imshow(frame.astype('uint8'))

# %% [markdown]
# ### 随机生成

# %%
import colorsys
import random

def get_n_hls_colors(num):
    hls_colors = []
    i = 0
    step = 360.0 / num
    while i < 360:
        h = i
        s = 90 + random.random() * 10
        l = 50 + random.random() * 10
        _hlsc = [h / 360.0, l / 100.0, s / 100.0]
        hls_colors.append(_hlsc)
        i += step

    return hls_colors

def ncolors(num):
    rgb_colors = []
    if num < 1:
        return rgb_colors
    hls_colors = get_n_hls_colors(num)
    for hlsc in hls_colors:
        _r, _g, _b = colorsys.hls_to_rgb(hlsc[0], hlsc[1], hlsc[2])
        r, g, b = [int(x * 255.0) for x in (_r, _g, _b)]
        rgb_colors.append([r, g, b])

    return rgb_colors

# %%
colors = ncolors(16)
colors = np.array(colors)
colors
# Out:
# array([[242,  24,  24],
#        [252, 120,  40],
#        [246, 199,  59],
#        [225, 252,  39],
#        [129, 251,   7],
#        [ 73, 254,  48],
#        [ 40, 254,  93],
#        [ 52, 250, 176],
#        [ 30, 254, 254],
#        [ 13, 162, 250],
#        [ 42,  94, 251],
#        [ 67,  41, 254],
#        [130,  10, 249],
#        [222,   1, 254],
#        [244,  55, 197],
#        [248,  16, 103]])

# %%
draw_colors(colors)

# %% [markdown]
# ## 根据标签将方框绘制在图片中

# %% [markdown]
# ### 读取图片

# %%
import cv2
import numpy as np
frame = cv2.imread(r"H:\deepLearning\dataset\visdrone\Task 1 - Object Detection in Images\train\VisDrone2019-DET-train\images\0000002_00005_d_0000014.jpg")

# %%
cv2.imwrite('frame.jpg',frame)
# Out:
# True

# %%
frame.shape
# Out:
# (540, 960, 3)

# %%
import pickle as pkl
import random
colors = pkl.load(open("pallete", "rb"))
print(random.choice(colors))
colors = np.array(colors)
# Out:
# (181, 64, 91)

# %% [markdown]
# ### label

# %%
label_path = r"H:\deepLearning\dataset\visdrone\Task 1 - Object Detection in Images\train\VisDrone2019-DET-train\annotations\0000002_00005_d_0000014.txt"
lbls = None
with open(label_path) as f:
    lbls = f.readlines()
    #print(lbls)
    
label = np.zeros((len(lbls),8))
print(label.shape)
for i,lbl in enumerate(lbls):
    res = [int(num) for num in lbl.split(',')]
    label[i,:] = np.array(res)
# Out:
# (88, 8)

# %%
idx = np.random.choice(range(len(colors)),16)
colors = colors[idx]

# %% [markdown]
# ### 叠加显示
# Note: rerun above codes first

# %%
label = label[4:10]
label
for i,lbl in enumerate(label):
    print(lbl)
    p1 = (int(lbl[0]), int(lbl[1]))
    p2 = (int(lbl[0]+lbl[2]), int(lbl[1]+lbl[3]))
    print(p1,p2)
    c = int(lbl[5])
    color = tuple(colors[c])
    #print(type(color[0])
    #print(color)
    cv2.rectangle(frame, p1, p2, (int(color[0]),int(color[1]),int(color[2])), 2)
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame.astype('uint8'))
#cv2.imwrite('frame.jpg',frame)
# Out:
# [708. 471.  74.  33.   1.   4.   0.   1.]
# (708, 471) (782, 504)
# [639. 425.  61.  46.   1.   4.   0.   0.]
# (639, 425) (700, 471)
# [594. 399.  64.  51.   1.   4.   0.   0.]
# (594, 399) (658, 450)
# [562. 390.  61.  38.   1.   4.   0.   0.]
# (562, 390) (623, 428)
# [540. 372.  65.  33.   1.   4.   0.   1.]
# (540, 372) (605, 405)
# [514. 333.  68.  35.   1.   4.   0.   0.]
# (514, 333) (582, 368)
